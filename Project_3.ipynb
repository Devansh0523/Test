# %% [markdown]
# <a href="https://colab.research.google.com/github/Devansh0523/Test/blob/main/Project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("/content/Project - 3(Covid Data).csv")
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# Q1:- Show the no. of confirmed cases, Deaths & Recovered Cases in each region?

# %%
data.head(3)

data.groupby("Region")["Confirmed", "Deaths"].sum()
# Out:
# <ipython-input-7-019921061102>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby("Region")["Confirmed", "Deaths"].sum()
#                     Confirmed  Deaths
# Region
# Afghanistan              1939      60
# Albania                   766      30
# Algeria                  3848     444
# Andorra                   743      42
# Angola                     27       2
# ...                       ...     ...
# West Bank and Gaza        344       2
# Western Sahara              6       0
# Yemen                       6       0
# Zambia                     97       3
# Zimbabwe                   32       4
#
# [187 rows x 2 columns]

# %% [markdown]
# Q2:- Remove all the records where Confirmed Cases is Less than 10.

# %%
data.head(3)

data[~(data.Confirmed<10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# Q3:- In which region, maximum number of confirmed cases were recorded?

# %%
data.head(3)

 data.groupby("Region").Confirmed.sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# Q4:- In which region, maximum number of Deaths cases were recorded?

# %%
data.head(3)

data.groupby("Region").Deaths.sum().sort_values(ascending=False)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26166
# Spain          24275
# France         24121
#                ...
# Holy See           0
# Grenada            0
# South Sudan        0
# Nepal              0
# Laos               0
# Name: Deaths, Length: 187, dtype: int64

# %% [markdown]
# Q5:- How many Confirmed, Deaths and Recovered cases were reported from India till 29th April 2020?

# %%
data.head(3)

data[data.Region == "India"]
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# Q6:- (A) Sort the enitre data with respect to No. of Confirmed Cases in ascending order.
#
# (B) Sort the enitre data with respect to No. of Recovered Cases in descending order.

# %%
data.head(3)

data.sort_values("Recovered" , ascending=False)
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]
